# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\mkrti\Downloads\ibm.csv')

data
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2019-09-01  128.919693  140.124283  127.466537  139.024857  110.706055
# 1   2019-10-01  139.187378  140.869980  125.143402  127.848946  101.806648
# 2   2019-11-01  128.585083  133.021027  126.912048  128.537292  102.354774
# 3   2019-12-01  128.537292  130.420654  124.942642  128.145309  103.247894
# 4   2020-01-01  129.063095  139.378586  127.342255  137.409180  110.711845
# ..         ...         ...         ...         ...         ...         ...
# 56  2024-05-01  165.690002  175.460007  162.619995  166.850006  165.209991
# 57  2024-06-01  166.539993  178.460007  163.529999  172.949997  172.949997
# 58  2024-07-01  173.449997  196.259995  173.380005  192.139999  192.139999
# 59  2024-08-01  192.809998  193.639999  185.699997  189.119995  189.119995
# 60  2024-08-05  184.550003  185.255005  181.809998  183.309998  183.309998
#
#        Volume
# 0    64655351
# 1    95625532
# 2    67751825
# ...

# %%
# Calculate descriptive statistics
descriptive_stats = data.describe()

# Extracting relevant columns for line graph
line_graph_data = data[['Date', 'Close']]

# Convert 'Date' column to datetime
line_graph_data['Date'] = pd.to_datetime(line_graph_data['Date'])

# Plotting the line graph for the 'Close' prices
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(line_graph_data['Date'], line_graph_data['Close'], marker='o')
plt.title('AAPL Stock Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price (USD)')
plt.grid(True)
plt.show()

descriptive_stats
# Out:
# C:\Users\mkrti\AppData\Local\Temp\ipykernel_29516\434742529.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   line_graph_data['Date'] = pd.to_datetime(line_graph_data['Date'])
#              Open        High         Low       Close   Adj Close  \
# count   61.000000   61.000000   61.000000   61.000000   61.000000
# mean   136.894478  144.949157  130.463182  137.708714  124.813050
# std     20.622401   21.204567   21.331309   21.585945   27.723333
# min    101.682602  118.881454   86.577438  106.051628   86.339043
# 25%    122.669998  130.990005  116.778206  122.510002  102.919136
# 50%    133.419998  139.579346  125.800003  133.570007  118.961151
# 75%    141.000000  147.729996  135.869995  141.190002  136.122086
# ...
